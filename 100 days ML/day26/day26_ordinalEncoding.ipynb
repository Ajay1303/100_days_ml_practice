# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 2    70  Female     Good        PG        No
# 10   98  Female     Good        UG       Yes
# 36   34  Female     Good        UG       Yes
# 0    30  Female  Average    School        No
# 42   30  Female     Good        PG       Yes

# %%
df= df.iloc[:,2:]

# %%
df.head(5)
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,:2],df['purchased'],test_size=0.3)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_train=oe.transform(x_train)
x_test=oe.transform(x_test)

# %%
x_train=pd.DataFrame(x_train,columns=['review','education'])

# %%
x_train
# Out:
#     review  education
# 0      1.0        2.0
# 1      1.0        0.0
# 2      2.0        2.0
# 3      1.0        1.0
# 4      2.0        0.0
# 5      0.0        1.0
# 6      2.0        1.0
# 7      1.0        1.0
# 8      0.0        2.0
# 9      1.0        2.0
# 10     2.0        2.0
# 11     1.0        2.0
# 12     2.0        1.0
# 13     2.0        1.0
# 14     1.0        0.0
# 15     2.0        0.0
# 16     0.0        2.0
# 17     0.0        1.0
# 18     1.0        1.0
# 19     1.0        0.0
# 20     1.0        1.0
# 21     0.0        2.0
# 22     2.0        1.0
# 23     2.0        0.0
# 24     2.0        2.0
# 25     0.0        2.0
# 26     0.0        0.0
# 27     2.0        2.0
# 28     1.0        1.0
# 29     0.0        2.0
# 30     2.0        0.0
# 31     0.0        0.0
# 32     0.0        2.0
# 33     2.0        2.0
# 34     2.0        1.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
y_train=le.transform(y_train)
y_test=le.transform(y_test)
